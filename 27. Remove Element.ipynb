# %%
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """

# %%
nums = [3,2,2,3]
val = 3
sol = Solution()
sol.removeElement(nums, val)

# %%
nums = [0,1,2,2,3,0,4,2]
val = 2
sol = Solution()
sol.removeElement(nums, val)
