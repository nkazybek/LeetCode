# %%
class Solution(object):
    def subsetXORSum(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        [1, 3]
        001
        011
        010
        """
        result = 0
        for i in nums:
            
        
        return result

# %%
nums = [1,3]
solution = Solution()
print(solution.subsetXORSum(nums))
# Out:
# 1
# 3
# 0

# %%
# Out:
# 4
