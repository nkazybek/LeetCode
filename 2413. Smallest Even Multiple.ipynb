# %%
class Solution(object):
    def smallestEvenMultiple(self, n):
        """
        :type n: int
        :rtype: int
        """

# %%
n = 5
sol = Solution()
sol.smallestEvenMultiple(n)

# %%
n = 6
sol = Solution()
sol.smallestEvenMultiple(n)
