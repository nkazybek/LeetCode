# %%
class Solution(object):
    def buildArray(self, nums):
        """
        :type nums: List[int]
        :rtype: List[int]
        """
        
        
        return 0

# %%
nums = [0,2,1,5,3,4]
solution = Solution()
print(solution.buildArray(nums))
# Out:
# 0

# %%
nums = [5,0,1,2,3,4]
solution = Solution()
print(solution.buildArray(nums))
